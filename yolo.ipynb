# %%
# !pip install ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 2.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 3.4 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 2.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/216.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/216.1 MB ? eta -:--:--
#    ---------------------------------------- 0.8/216.1 MB 2.2 MB/s eta 0:01:37
#    ---------------------------------------- 1.3/216.1 MB 2.5 MB/s eta 0:01:27
#    ---------------------------------------- 2.1/216.1 MB 2.7 MB/s eta 0:01:19
#     --------------------------------------- 2.9/216.1 MB 2.9 MB/s eta 0:01:13
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Shravan Shetty\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:02<00:00, 3.22MB/s]

# %%
results=model("WhatsApp Image 2025-06-14 at 10.31.18_95b8f030.jpg")
# Out:
# image 1/1 C:\Users\Shravan Shetty\WhatsApp Image 2025-06-14 at 10.31.18_95b8f030.jpg: 480x640 5 cars, 1 truck, 2 traffic lights, 135.7ms
# Speed: 11.1ms preprocess, 135.7ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)

# %%
results[0].show()

# %%
results[0].save(filename="output.jpg")
# Out:
# 'output.jpg'
